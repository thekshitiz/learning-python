# %%
import pandas as pd

# %%
l1 = [3, 6 , -7, 2]

# %%
l1
# Out:
# [3, 6, -7, 2]

# %%
s1 = pd.Series(l1)

# %%
s1
# Out:
# 0    3
# 1    6
# 2   -7
# 3    2
# dtype: int64

# %%
l2 = [1,2,'3',4]

# %%
s2 = pd.Series(l2)

# %%
s2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: object

# %%
type(s1[0])
# Out:
# numpy.int64

# %%
s1
# Out:
# 0    3
# 1    6
# 2   -7
# 3    2
# dtype: int64

# %%
s1 * 2
# Out:
# 0     6
# 1    12
# 2   -14
# 3     4
# dtype: int64

# %%
s1.values
# Out:
# array([ 3,  6, -7,  2], dtype=int64)

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s3 = pd.Series(l1, index=[3,4,1,2])

# %%
s3
# Out:
# 3    3
# 4    6
# 1   -7
# 2    2
# dtype: int64

# %%
d = {'Denmark':2, 'nepal':1, 'china':3 }

# %%
d
# Out:
# {'Denmark': 2, 'nepal': 1, 'china': 3}

# %%
s4 = pd.Series(d)

# %%
s4
# Out:
# Denmark    2
# nepal      1
# china      3
# dtype: int64

# %%
d2 = {'Denmark':3, 'udayapur':2, 'dharan':1}

# %%
s5 = pd.Series(d2)

# %%
s5
# Out:
# Denmark     3
# udayapur    2
# dharan      1
# dtype: int64

# %%
s4 + s5
# Out:
# Denmark     5.0
# china       NaN
# dharan      NaN
# nepal       NaN
# udayapur    NaN
# dtype: float64
